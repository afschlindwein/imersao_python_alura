# %% [markdown]
# <a href="https://colab.research.google.com/github/afschlindwein/imersao_python_alura/blob/main/Aula_2_Imers%C3%A3o_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **AULA 2 - IMPORTAÇÃO**

# %%
import pandas as pd

# %%
df_principal = pd.read_excel('/Imersão Python - Tabela de ações.xlsx', sheet_name='Principal')
df_principal.head(10)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0  USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1  CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2  PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3  SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4  CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# 5  PRIO3 2024-01-26        45.69          1.98           2.42         -0.78
# 6  PETR4 2024-01-26        39.96          1.73           6.47          7.30
# 7  VALE3 2024-01-26        69.50          1.66           2.06         -9.97
# 8  MULT3 2024-01-26        28.19          1.58           2.03         -0.81
# 9  ITUB4 2024-01-26        32.81          1.48          -0.39         -3.36
#
#    Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ...  Variação $.1  \
# ...

# %%
df_total_acoes = pd.read_excel('/Imersão Python - Tabela de ações.xlsx', sheet_name='Total_de_acoes')
df_total_acoes.head(10)
# Out:
#   Código  Qtde. Teórica
# 0  RRRP3   2.356656e+08
# 1  ALOS3   5.326166e+08
# 2  ALPA4   1.767340e+08
# 3  ABEV3   4.394246e+09
# 4  ARZZ3   6.230589e+07
# 5  ASAI3   1.349218e+09
# 6  AZUL4   3.275937e+08
# 7  B3SA3   5.602790e+09
# 8  BBSE3   6.717508e+08
# 9  BBDC3   1.500729e+09

# %%
df_ticker = pd.read_excel('/Imersão Python - Tabela de ações.xlsx', sheet_name='Ticker')
df_ticker.head(10)
# Out:
#   Ticker            Nome
# 0  MGLU3  Magazine Luiza
# 1  HAPV3         Hapvida
# 2  PETR4       Petrobras
# 3  B3SA3              B3
# 4  USIM5        Usiminas
# 5  CVCB3             CVC
# 6  CIEL3           Cielo
# 7  VALE3            Vale
# 8  GOLL4             GOL
# 9  BBDC4  Banco Bradesco

# %%
df_chatgpt = pd.read_excel('/Imersão Python - Tabela de ações.xlsx', sheet_name='Chat_GPT')
df_chatgpt.head(10)
# Out:
#   Nome da Empresa          Segmento  Idade (em anos)
# 0        Usiminas        Siderurgia               70
# 1   CSN Mineração         Mineração               15
# 2       Petrobras          Petróleo               69
# 3          Suzano  Papel e Celulose               96
# 4    CPFL Energia           Energia              108
# 5        PetroRio          Petróleo               12
# 6       Petrobras          Petróleo               69
# 7            Vale         Mineração               79
# 8       Multiplan  Shopping Centers               49
# 9   Itaú Unibanco             Banco               78
